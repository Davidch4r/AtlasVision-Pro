# %%
from geoguessr import Game

# %%
game = Game()
print(game.agent.model.summary())
# Out:
# Model loaded from Models/agent_model.keras
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 298, 298, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 149, 149, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 147, 147, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 73, 73, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# # Training

# %%
game.play_rounds(10, show=False, learn=True, save_after=10, show_after=-1)
# Out:
# Round 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step - loss: 0.0567
# Round 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step - loss: 0.1013
# Round 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step - loss: 0.1917
# Round 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step - loss: 0.3378
# Round 5/10
# Failed to find a location with Street View availability after multiple attempts.
# Round 6/10
# ...

# %% [markdown]
# # Testing

# %%
game.play_rounds(5, show=True, learn=False, heat=True)
# Out:
# Round 1/5
# (41.15411316422571, -78.11244392001095)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Correct [Norm]: [0.79812593 0.65977358] | Agent [Norm]: [0.5914336  0.50938624]
# Correct [Denorm]: [-78.11244392001095, 41.15411316422571] | Agent [Denorm]: [-90.51398492  37.24404228]
# Round 2/5
# (43.49728633609057, -79.709710924924)e.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Correct [Norm]: [0.77150482 0.74989563] | Agent [Norm]: [0.5685564 0.5261771]
# Correct [Denorm]: [-79.709710924924, 43.49728633609057] | Agent [Denorm]: [-91.88661432  37.68060482]
# Round 3/5
# (41.54745544807069, -73.72785374076201)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Correct [Norm]: [0.87120244 0.67490213] | Agent [Norm]: [0.516405  0.5204048]
# Correct [Denorm]: [-73.72785374076201, 41.54745544807069] | Agent [Denorm]: [-95.01570082  37.53052521]
# Round 4/5
# (32.16681973257283, -89.95657021247882)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# ...
