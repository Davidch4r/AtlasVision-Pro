# %%
from geoguessr import Game

# %%
game = Game()
print(game.agent.model.summary())
# Out:
# Model loaded from Models/agent_model.keras
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 298, 298, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 149, 149, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 147, 147, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 73, 73, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 71, 71, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 645248)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    82,591,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 82,684,802 (315.42 MB)
#  Trainable params: 82,684,802 (315.42 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# # Training

# %%
game.play_rounds(10, show=False, learn=True, save_after=10, show_after=-1)
# Out:
# Round 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step - loss: 0.0016
# Round 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step - loss: 0.2377
# Round 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step - loss: 0.3401
# Round 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 667ms/step - loss: 0.3704
# Round 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step - loss: 0.4142
# Round 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step - loss: 0.1603
# Round 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step - loss: 0.0143
# Round 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step - loss: 0.0323
# Round 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 585ms/step - loss: 6.4914e-04
# Round 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step - loss: 0.0174
# Model saved at Models/agent_model.keras
# Model saved at Models/agent_model.keras

# %% [markdown]
# # Testing

# %%
game.play_rounds(5, show=True, learn=False, heat=True)
# Out:
# Round 1/5
# (35.34580984186181, -80.63639021406544)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Correct [Norm]: [0.75606016 0.4363773 ] | Agent [Norm]: [0.53991055 0.40751803]
# Correct [Denorm]: [-80.63639021406544, 35.34580984186181] | Agent [Denorm]: [-93.60536671  34.59546876]
# Round 2/5
# (30.786403968716197, -85.4521642649515)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Correct [Norm]: [0.67579726 0.26101554] | Agent [Norm]: [0.55629003 0.40312278]
# Correct [Denorm]: [-85.4521642649515, 30.786403968716197] | Agent [Denorm]: [-92.62259817  34.48119235]
# Round 3/5
# (44.29510477355285, -76.78036661396276)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Correct [Norm]: [0.82032722 0.78058095] | Agent [Norm]: [0.5614825  0.39883456]
# Correct [Denorm]: [-76.78036661396276, 44.29510477355285] | Agent [Denorm]: [-92.31105065  34.36969846]
# Round 4/5
# (42.97568349785346, -78.92827429902329)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Correct [Norm]: [0.78452876 0.72983398] | Agent [Norm]: [0.53620756 0.42073968]
# Correct [Denorm]: [-78.92827429902329, 42.97568349785346] | Agent [Denorm]: [-93.8275466   34.93923169]
# Round 5/5
# (40.125514659833755, -75.50938872889989)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Correct [Norm]: [0.84151019 0.6202121 ] | Agent [Norm]: [0.5948554 0.3687136]
# Correct [Denorm]: [-75.50938872889989, 40.125514659833755] | Agent [Denorm]: [-90.30867434  33.58655328]
# Model saved at Models/agent_model.keras
